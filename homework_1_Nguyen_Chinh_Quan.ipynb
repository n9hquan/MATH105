# %% [markdown]
# Homework 1 - Chapter 2
# Author: Nguyen Chinh Quan (220066)

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import sys
import stemgraphic

# %% [markdown]
# 2.13.

# %% [markdown]
# a. discrete //
# b. categorical //
# c. continuous //
# d. continuous //
# e. categorical //
# f. continuous //

# %% [markdown]
# 2.38.

# %% [markdown]
# a.

# %%
# I have calculated the missing values in relative frequency and frequency columns before putting them into the table for display.
df_38 = pd.DataFrame(
    { "Response": ['Excellent', 'Very good', 'Good', 'Fair', 'Poor'],
    "Frequency": [50, 152, 255, 425, 118],
    "Relative Frequency": [0.05, 0.152, 0.255, 0.4250, 0.1180]},
    )
df_38
# Out:
#     Response  Frequency  Relative Frequency
# 0  Excellent         50               0.050
# 1  Very good        152               0.152
# 2       Good        255               0.255
# 3       Fair        425               0.425
# 4       Poor        118               0.118

# %% [markdown]
# b.

# %%
bar_chart_38 = df_38.plot.bar( x = "Response", y = 'Frequency', rot = 0)

# %%
pie_chart_38 = df_38.plot.pie(y = "Frequency", labels = df_38.Response)

# %% [markdown]
# c.

# %%
customers_excellent = (df_38[df_38["Response"] == "Excellent"].Frequency) / sum(df_38.Frequency)
customers_very_good = (df_38[df_38["Response"] == "Very good"].Frequency) / sum(df_38.Frequency)
proportion_did_not_rank_good_or_excellent = (1 - customers_excellent[0] - customers_very_good[1]) * 100
proportion_did_not_rank_good_or_excellent
# Out:
# 79.8

# %% [markdown]
# 2.42.

# %%
data_42 = pd.read_excel(r"D:\stat\Tex-_Datasets\Chapter 2\ex02-42ratings.xls")
data_42
# Out:
#       Rating  Men Frequency  Women Frequency
# 0  Excellent            368              350
# 1  Very Good            550              375
# 2       Good            426              165
# 3       Fair            450              360
# 4       Poor            206              250

# %% [markdown]
# a.

# %%
data_42["Men Relative Frequency"] = data_42.iloc[:,1] / data_42["Men Frequency"].sum()
data_42["Women Relative Frequency"] = round((data_42.iloc[:,2] / data_42["Women Frequency"].sum()),3)
data_42
# Out:
#       Rating  Men Frequency  Women Frequency  Men Relative Frequency  \
# 0  Excellent            368              350                   0.184
# 1  Very Good            550              375                   0.275
# 2       Good            426              165                   0.213
# 3       Fair            450              360                   0.225
# 4       Poor            206              250                   0.103
#
#    Women Relative Frequency
# 0                     0.233
# 1                     0.250
# 2                     0.110
# 3                     0.240
# 4                     0.167

# %% [markdown]
# b.

# %%
bar_chart_42 = data_42.plot(x = "Rating", y = ["Men Relative Frequency", "Women Relative Frequency"], kind = "bar", rot = 0)

# %% [markdown]
# c.

# %% [markdown]
# Relative frequency should be used for comparison in the side-by-side bar chart than frequency because it allows us to view the data for each category in terms of percentages compared to the whole data set rather than just the individual counts.

# %% [markdown]
# 2.62

# %% [markdown]
# a.

# %%
data_62 = pd.read_excel(r"D:\stat\Tex-_Datasets\Chapter 2\ex02-62dishlife.xls")
# data_62

# %%
# data_62.Years.sort_values()

# %%
stemgraphic.stem_graphic(data_62.Years, aggregation= False)
# Out:
# (<Figure size 750x450 with 1 Axes>, <Axes: >)

# %% [markdown]
# b.

# %%
data_62.Years.plot(kind = 'hist', bins = 8)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# b.

# %%
data_62.Years.median()
# The distribution is skewed to the right, centered around 11.1, and has a lot of variability.
# Out:
# 11.1

# %% [markdown]
# c.

# %%
data_62.mode()
# Out:
#    Years
# 0   11.1

# %%
data_62.describe()
# Out:
#            Years
# count  40.000000
# mean   11.552500
# std     3.213273
# min     6.500000
# 25%     9.175000
# 50%    11.100000
# 75%    12.825000
# max    20.200000

# %%
q1 = 9.175000
q2 = 11.100000
q3 = 12.825000
IQR = q3 - q1
lower = q1 - 1.5*IQR
upper = q3 + 1.5*IQR
data_62.Years[(data_62.Years > upper) | (data_62.Years < lower)]
# 2 outliers: 19.4 and 20.2 years
# Out:
# 5     19.4
# 32    20.2
# Name: Years, dtype: float64

# %% [markdown]
# 2.95.

# %%
data_95 = pd.read_excel(r"D:\stat\Tex-_Datasets\Chapter 2\ex02-95carcost.xls")
# data_95

# %% [markdown]
# a.

# %%
data_95.Problems.plot(kind = 'hist', bins = 8)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# b.

# %%
data_95.Problems.median() 
# The distribution is skewed to the right, centered around 133.5, and has a lot of variability.
# Out:
# 133.5

# %% [markdown]
# c.

# %%
Q1 = data_95.Problems.quantile(0.25)
Q3 = data_95.Problems.quantile(0.75)
print(data_95[(data_95.Problems < Q1)].value_counts().sum(), data_95[(data_95.Problems > Q3)].value_counts().sum())
#8 values below 25% and 8 values above 75%. Because we have 32 values of brands in total, we expect the numbers between Q1 and Q3 to be 
# 36 - 8 - 8 = 16
# Out:
# 8 8

# %%
print(Q1, Q3)
# Out:
# 121.5 149.25

# %% [markdown]
# d.

# %%
data_95[(data_95.Problems > Q1) & (data_95.Problems < Q3)].value_counts().sum()
#16 values between Q1 and Q3
# Out:
# 16
