# %% [markdown]
# 6.70.

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
import numpy as np
# Your data
data = [15.4, 13.9, 14.9, 16.2, 16.6, 15.4, 17.2, 18.5, 19.3, 13.0, 16.5, 20.2, 16.4, 15.3, 18.5, 17.9, 15.5, 17.4, 16.3, 14.3]
np_data = np.array(data)
# Create QQ plot
sm.qqplot(np_data)
plt.show()
